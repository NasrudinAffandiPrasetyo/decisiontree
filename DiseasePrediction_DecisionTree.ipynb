# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./Testing.csv")
df.describe()
# Out:
#          itching  skin_rash  nodal_skin_eruptions  continuous_sneezing  \
# count  42.000000  42.000000             42.000000            42.000000
# mean    0.166667   0.190476              0.023810             0.047619
# std     0.377195   0.397437              0.154303             0.215540
# min     0.000000   0.000000              0.000000             0.000000
# 25%     0.000000   0.000000              0.000000             0.000000
# 50%     0.000000   0.000000              0.000000             0.000000
# 75%     0.000000   0.000000              0.000000             0.000000
# max     1.000000   1.000000              1.000000             1.000000
#
#        shivering     chills  joint_pain  stomach_pain    acidity  \
# count  42.000000  42.000000   42.000000     42.000000  42.000000
# mean    0.023810   0.166667    0.142857      0.047619   0.047619
# std     0.154303   0.377195    0.354169      0.215540   0.215540
# min     0.000000   0.000000    0.000000      0.000000   0.000000
# 25%     0.000000   0.000000    0.000000      0.000000   0.000000
# 50%     0.000000   0.000000    0.000000      0.000000   0.000000
# 75%     0.000000   0.000000    0.000000      0.000000   0.000000
# max     1.000000   1.000000    1.000000      1.000000   1.000000
#
#        ulcers_on_tongue  ...  pus_filled_pimples  blackheads   scurring  \
# count         42.000000  ...           42.000000   42.000000  42.000000
# mean           0.023810  ...            0.023810    0.023810   0.023810
# std            0.154303  ...            0.154303    0.154303   0.154303
# min            0.000000  ...            0.000000    0.000000   0.000000
# 25%            0.000000  ...            0.000000    0.000000   0.000000
# 50%            0.000000  ...            0.000000    0.000000   0.000000
# 75%            0.000000  ...            0.000000    0.000000   0.000000
# max            1.000000  ...            1.000000    1.000000   1.000000
#
#        skin_peeling  silver_like_dusting  small_dents_in_nails  \
# count     42.000000            42.000000             42.000000
# mean       0.047619             0.023810              0.023810
# std        0.215540             0.154303              0.154303
# min        0.000000             0.000000              0.000000
# 25%        0.000000             0.000000              0.000000
# 50%        0.000000             0.000000              0.000000
# 75%        0.000000             0.000000              0.000000
# max        1.000000             1.000000              1.000000
#
#        inflammatory_nails    blister  red_sore_around_nose  yellow_crust_ooze
# count           42.000000  42.000000             42.000000          42.000000
# mean             0.023810   0.023810              0.047619           0.023810
# std              0.154303   0.154303              0.215540           0.154303
# min              0.000000   0.000000              0.000000           0.000000
# 25%              0.000000   0.000000              0.000000           0.000000
# 50%              0.000000   0.000000              0.000000           0.000000
# 75%              0.000000   0.000000              0.000000           0.000000
# max              1.000000   1.000000              1.000000           1.000000
#
# [8 rows x 132 columns]

# %%
df.shape
# Out:
# (42, 133)

# %%
df.drop('Unnamed: 133', axis=1, inplace=True, errors='ignore')

# %%
df['prognosis'].value_counts()
# Out:
# prognosis
# Fungal infection                           2
# Hepatitis C                                1
# Hepatitis E                                1
# Alcoholic hepatitis                        1
# Tuberculosis                               1
# Common Cold                                1
# Pneumonia                                  1
# Dimorphic hemmorhoids(piles)               1
# Heart attack                               1
# Varicose veins                             1
# Hypothyroidism                             1
# Hyperthyroidism                            1
# Hypoglycemia                               1
# Osteoarthristis                            1
# Arthritis                                  1
# (vertigo) Paroymsal  Positional Vertigo    1
# Acne                                       1
# Urinary tract infection                    1
# Psoriasis                                  1
# Hepatitis D                                1
# Hepatitis B                                1
# Allergy                                    1
# hepatitis A                                1
# GERD                                       1
# Chronic cholestasis                        1
# Drug Reaction                              1
# Peptic ulcer diseae                        1
# AIDS                                       1
# Diabetes                                   1
# Gastroenteritis                            1
# Bronchial Asthma                           1
# Hypertension                               1
# Migraine                                   1
# Cervical spondylosis                       1
# Paralysis (brain hemorrhage)               1
# Jaundice                                   1
# Malaria                                    1
# Chicken pox                                1
# Dengue                                     1
# Typhoid                                    1
# Impetigo                                   1
# Name: count, dtype: int64

# %%
x = df.drop('prognosis', axis = 1)
y = df['prognosis']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = tree.predict(x_test)
acc = tree.score(x_test, y_test)

print("Acurray on test set: {:.2f}%".format(acc*100))
# Out:
# Acurray on test set: 0.00%

# %%
fi = pd.DataFrame(tree.feature_importances_*100, x_test.columns, columns=['Importance'])
fi.sort_values(by='Importance',ascending=False, inplace=True)
fi
# Out:
#                        Importance
# fatigue                  4.773663
# skin_rash                4.765432
# itching                  4.534979
# muscle_pain              3.580247
# distention_of_abdomen    3.580247
# ...                           ...
# fluid_overload           0.000000
# acute_liver_failure      0.000000
# yellowing_of_eyes        0.000000
# yellow_urine             0.000000
# yellow_crust_ooze        0.000000
#
# [132 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# fi['Importance'].plot(kind='hist', bins=20, title='Importance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# fi['Importance'].plot(kind='line', figsize=(8, 4), title='Importance')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
zeros = np.array(fi[fi['Importance'] <= 2.300000].index)
zeros
# Out:
# array(['movement_stiffness', 'silver_like_dusting',
#        'continuous_feel_of_urine', 'bladder_discomfort', 'loss_of_smell',
#        'weakness_of_one_body_side', 'small_dents_in_nails',
#        'loss_of_balance', 'spinning_movements', 'blood_in_sputum',
#        'swelling_joints', 'skin_peeling', 'inflammatory_nails',
#        'muscle_weakness', 'hip_joint_pain', 'blister', 'slurred_speech',
#        'drying_and_tingling_lips', 'extra_marital_contacts',
#        'red_sore_around_nose', 'internal_itching', 'irritability',
#        'depression', 'mucoid_sputum', 'history_of_alcohol_consumption',
#        'prominent_veins_on_calf', 'stomach_bleeding', 'palpitations',
#        'painful_walking', 'receiving_unsterile_injections',
#        'visual_disturbances', 'lack_of_concentration', 'rusty_sputum',
#        'blackheads', 'fluid_overload.1', 'scurring', 'polyuria',
#        'increased_appetite', 'watering_from_eyes', 'dischromic _patches',
#        'abnormal_menstruation', 'belly_pain', 'red_spots_over_body',
#        'altered_sensorium', 'swollen_extremeties', 'bruising',
#        'enlarged_thyroid', 'patches_in_throat', 'back_pain',
#        'pain_behind_the_eyes', 'nausea', 'dark_urine', 'yellowish_skin',
#        'headache', 'indigestion', 'dehydration', 'breathlessness',
#        'sunken_eyes', 'high_fever', 'irregular_sugar_level', 'lethargy',
#        'abdominal_pain', 'weight_loss', 'cold_hands_and_feets', 'anxiety',
#        'weight_gain', 'spotting_ urination', 'burning_micturition',
#        'muscle_wasting', 'ulcers_on_tongue', 'stomach_pain', 'chills',
#        'shivering', 'nodal_skin_eruptions', 'constipation', 'diarrhoea',
#        'puffy_face_and_eyes', 'congestion', 'swollen_blood_vessels',
#        'swollen_legs', 'obesity', 'cramps', 'dizziness', 'neck_pain',
#        'irritation_in_anus', 'pain_in_anal_region',
#        'pain_during_bowel_movements', 'fast_heart_rate',
#        'weakness_in_limbs', 'chest_pain', 'runny_nose', 'mild_fever',
#        'sinus_pressure', 'redness_of_eyes', 'throat_irritation', 'phlegm',
#        'blurred_and_distorted_vision', 'malaise', 'swelled_lymph_nodes',
#        'swelling_of_stomach', 'fluid_overload', 'acute_liver_failure',
#        'yellowing_of_eyes', 'yellow_urine', 'yellow_crust_ooze'],
#       dtype=object)

# %%
training_new = df.drop(columns=zeros, axis=1)
training_new.shape[1]
training_new.columns
# Out:
# Index(['itching', 'skin_rash', 'continuous_sneezing', 'joint_pain', 'acidity',
#        'vomiting', 'fatigue', 'mood_swings', 'restlessness', 'cough',
#        'sweating', 'loss_of_appetite', 'bloody_stool', 'brittle_nails',
#        'excessive_hunger', 'knee_pain', 'stiff_neck', 'unsteadiness',
#        'foul_smell_of urine', 'passage_of_gases', 'toxic_look_(typhos)',
#        'muscle_pain', 'family_history', 'receiving_blood_transfusion', 'coma',
#        'distention_of_abdomen', 'pus_filled_pimples', 'prognosis'],
#       dtype='object')

# %%
def modelling(df1):
    x_new = df1.drop('prognosis', axis = 1)
    y_new = df1.prognosis
    x_train_new, x_test_new, y_train_new, y_test_new = train_test_split(x_new, y_new, test_size=0.3, random_state=42)
    tree.fit(x_train_new, y_train_new)

    pred_new = tree.predict(x_test_new)

    acc_new = tree.score(x_test_new, y_test_new)
#     a = mean_absolute_error(y_test_new, pred_new)
    print("Acurray on test set: {:.2f}%".format(acc*100))
#     print("mean_absolute_error of the test set: {:.2f}%".format(a))

# %%
test = pd.read_csv("./Testing.csv")
test_new = test.drop(columns=zeros, axis=1)
test_new.shape[1]
# Out:
# 28

# %%
modelling(test_new)
# Out:
# Acurray on test set: 0.00%
